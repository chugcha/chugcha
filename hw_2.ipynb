# %% [markdown]
# <a href="https://colab.research.google.com/github/chugcha/chugcha/blob/main/hw_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Домашнее задание 2**

# %%
with open('/bazhov1tom.txt', 'r', encoding='utf-8') as book:
    book = book.read()
